# %% [markdown]
# <a href="https://colab.research.google.com/github/sunohk/dataon_pj/blob/main/%ED%95%99%EC%8A%B5_%EC%BD%94%EB%93%9C/0_Data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. SNS 트위터, 인스타그램 전처리
# ## - Package 설치

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd

# 합칠 Excel 파일의 경로
file_paths = ['/gdrive/MyDrive/finalproject/datasets/Raw/youthpolicy/Analysis_SnsData_20211001_20230626_(청년정책)&&~(rt__독취사)_BY_ARGOS.xlsx',
              '/gdrive/MyDrive/finalproject/datasets/Raw/youthpolicy/Analysis_SnsData_20190501_20210930_(청년정책)&&~(rt__독취사)_BY_ARGOS.xlsx']

# 빈 DataFrame 생성
youth_df = pd.DataFrame()

# 각 파일의 특정 시트를 읽어와서 DataFrame에 추가
for file_path in file_paths:
    xls = pd.ExcelFile(file_path)
    for sheet_name in xls.sheet_names:
        if sheet_name not in ['인스타그램', '트위터']:  # 시트명이 "블로그" 또는 "커뮤니티"가 아닌 시트는 제외
            continue
        sheet_df = pd.read_excel(xls, sheet_name, skiprows=1)
        sheet_df['구분'] = sheet_name  # 시트명으로 구분하는 컬럼 추가
        youth_df = pd.concat([youth_df, sheet_df])

# '작성일' 기준으로 오름차순 정렬
youth_df = youth_df.sort_values(by='작성일')

# 합쳐진 DataFrame을 새로운 Excel 파일로 저장
output_path = '/gdrive/MyDrive/finalproject/datasets/final/youth_sns(ins,twitter)_df(test).xlsx'
youth_df.to_excel(output_path, index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 저장한 엑셀 파일의 경로
saved_excel_path = '/gdrive/MyDrive/finalproject/datasets/final/youth_sns(ins,twitter)_df(test).xlsx'

# 엑셀 파일을 DataFrame으로 읽어오기
youth_sns_df = pd.read_excel(saved_excel_path)

# DataFrame의 헤더 출력
youth_sns_df.head()
# Out:
#           작성일              작성자  제목  \
# 0  2019/05/01  gyeongsangbukdo NaN
# 1  2019/05/01         imsena03 NaN
# 2  2019/05/01       mentorcore NaN
# 3  2019/05/01       maroon72kr NaN
# 4  2019/05/01         imsena03 NaN
#
#                                                   내용     구분
# 0  #공예업체 _취업을 원하는 \n경북의 취준생들에게 꿀 정보??\n#경상북도 #청년정...    트위터
# 1  2019년 행정안전부 지역주도형 청년일자리 사업으로 선정된 「용인지역명소 활성화 추...  인스타그램
# 2  안양 핫플레이스 중 한곳인 롯데시네마 영화 상영관 표 확인하곳 바로 옆에 이렇게 청...  인스타그램
# 3  @Jaemyung_Lee 흠.. 트윗영상 업로드 펄러시가 바뀐게 확실해요.\n올리는...    트위터
# 4  2019년 청년인턴 추가채용 계획을 붙임과 같이 공고합니다. - 채용분야 및 인원 ...  인스타그램

# %%
youth_sns_df.shape
# Out:
# (16141, 5)

# %% [markdown]
# ## 2-1. 결측치 제거

# %%
youth_sns_df.isna()
# Out:
#          작성일    작성자    제목     내용     구분
# 0      False  False  True  False  False
# 1      False  False  True  False  False
# 2      False  False  True  False  False
# 3      False  False  True  False  False
# 4      False  False  True  False  False
# ...      ...    ...   ...    ...    ...
# 16136  False  False  True  False  False
# 16137  False  False  True  False  False
# 16138  False  False  True  False  False
# 16139  False  False  True  False  False
# 16140  False  False  True  False  False
#
# [16141 rows x 5 columns]

# %% [markdown]
# - 인스타, 트위터 데이터는 제목 컬럼이 null 값이라 별도 결측치 처리

# %%
# '제목' 컬럼을 제외한 컬럼들에 대해 dropna 진행
youth_sns_df.dropna(subset=youth_sns_df.columns.difference(['제목']), inplace=True)

# 인덱스 리셋
youth_sns_df.reset_index(drop=True, inplace=True)

# 데이터프레임 정보 출력
youth_sns_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16141 entries, 0 to 16140
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   작성일     16141 non-null  object
#  1   작성자     16141 non-null  object
#  2   제목      0 non-null      float64
#  3   내용      16141 non-null  object
#  4   구분      16141 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 630.6+ KB

# %%
youth_sns_df.head()
# Out:
#           작성일              작성자  제목  \
# 0  2019/05/01  gyeongsangbukdo NaN
# 1  2019/05/01         imsena03 NaN
# 2  2019/05/01       mentorcore NaN
# 3  2019/05/01       maroon72kr NaN
# 4  2019/05/01         imsena03 NaN
#
#                                                   내용     구분
# 0  #공예업체 _취업을 원하는 \n경북의 취준생들에게 꿀 정보??\n#경상북도 #청년정...    트위터
# 1  2019년 행정안전부 지역주도형 청년일자리 사업으로 선정된 「용인지역명소 활성화 추...  인스타그램
# 2  안양 핫플레이스 중 한곳인 롯데시네마 영화 상영관 표 확인하곳 바로 옆에 이렇게 청...  인스타그램
# 3  @Jaemyung_Lee 흠.. 트윗영상 업로드 펄러시가 바뀐게 확실해요.\n올리는...    트위터
# 4  2019년 청년인턴 추가채용 계획을 붙임과 같이 공고합니다. - 채용분야 및 인원 ...  인스타그램

# %% [markdown]
# ## 2-2. 정제(Cleaning)
# - 정제(cleaning) : 갖고 있는 코퍼스(말뭉치)로부터 노이즈 데이터를 제거한다.

# %% [markdown]
# ### 전처리 사용자 정의 함수(최종 & 불용어 리스트 2차 필터)

# %%
# 텍스트 전처리 사용자 정의함수(UDF of text pre-processing)
def text_preprocessor(s):
    import re

    ## (1) 이메일, 링크
    pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'  # http
    s = re.sub(pattern=pattern, repl=' ', string=s)

    pattern = r'(?<=\S)www(?=\s|$)|(?<=\s)www(?=\s|$)'  # www
    s = re.sub(pattern=pattern, repl=' ', string=s)

    pattern = r'(?<=\S)@(?=\s|$)|(?<=\s)@(?=\s|$)'  # @
    s = re.sub(pattern=pattern, repl=' ', string=s)

    ## (2) 특수문자, 숫자
    pattern = r'[^a-zA-Z가-힣]'
    s = re.sub(pattern=pattern, repl=' ', string=s)

    ## (3) 단위, 기타(‘\n’,’\r’, ‘#’)
    units = ['mm', 'cm', 'km', 'ml', 'kg', 'g']
    for unit in units:
        s = s.lower()  # 대문자를 소문자로 변환
        s = re.sub(pattern=unit, repl='', string=s)

    pattern = r'[\n\r#]'
    s = re.sub(pattern=pattern, repl=' ', string=s)

    ## (4) 하나의 자음, 모음(ex.ㅋㅋㅋ), 한 글자
    pattern = r'(?![ㄱ-ㅣ가-힣])\w{1}'
    s = re.sub(pattern=pattern, repl='', string=s)

    # (5) 작성자
    # 작성자 컬럼의 고유한 값 추출
    unique_authors = youth_sns_df['작성자'].unique()

    # 작성자 컬럼과 제목, 내용 컬럼을 비교하여 동일한 내용 제외
    s = re.sub(rf'(?i)\b(?:{"|".join(map(re.escape, unique_authors))})\b', '', s)

    return s

# 완전 중복 행 제거
youth_sns_df = youth_sns_df.drop_duplicates()
youth_sns_df = youth_sns_df.reset_index(drop=True)

# '내용' 컬럼에 대해 전처리 함수 적용
youth_sns_df['clean_text'] = youth_sns_df['내용'].apply(text_preprocessor)

# 결과 출력
youth_sns_df
# Out:
#               작성일              작성자  제목  \
# 0      2019/05/01  gyeongsangbukdo NaN
# 1      2019/05/01         imsena03 NaN
# 2      2019/05/01       mentorcore NaN
# 3      2019/05/01       maroon72kr NaN
# 4      2019/05/01         imsena03 NaN
# ...           ...              ...  ..
# 15894  2023/06/26      youthseoul_ NaN
# 15895  2023/06/26       zozomoonli NaN
# 15896  2023/06/26    ansancityhall NaN
# 15897  2023/06/26         tyche811 NaN
# 15898  2023/06/26   OhmyNews_Korea NaN
#
#                                                       내용     구분  \
# 0      #공예업체 _취업을 원하는 \n경북의 취준생들에게 꿀 정보??\n#경상북도 #청년정...    트위터
# 1      2019년 행정안전부 지역주도형 청년일자리 사업으로 선정된 「용인지역명소 활성화 추...  인스타그램
# 2      안양 핫플레이스 중 한곳인 롯데시네마 영화 상영관 표 확인하곳 바로 옆에 이렇게 청...  인스타그램
# 3      @Jaemyung_Lee 흠.. 트윗영상 업로드 펄러시가 바뀐게 확실해요.\n올리는...    트위터
# 4      2019년 청년인턴 추가채용 계획을 붙임과 같이 공고합니다. - 채용분야 및 인원 ...  인스타그램
# ...                                                  ...    ...
# ...

# %% [markdown]
# - 불용어 제거

# %%
! git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
! bash Mecab-ko-for-Google-Colab/install_mecab-ko_on_colab_light_220429.sh
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 138, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 138 (delta 26), reused 22 (delta 8), pack-reused 91
# Receiving objects: 100% (138/138), 1.72 MiB | 4.24 MiB/s, done.
# Resolving deltas: 100% (65/65), done.
# Installing konlpy.....
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 23.8 MB/s eta 0:00:00
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2023-09-25 02:17:37--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22cd:e0db
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# ...

# %%
from konlpy.tag import Mecab#mecab 선언
mecab = Mecab()

# %%
from konlpy.tag import Mecab
import pandas as pd

mecab = Mecab()

# StopWordKorean.csv 파일 로드
stop_words_df = pd.read_csv('/gdrive/MyDrive/finalproject/datasets/StopWordKorean.csv', header=None, encoding='cp949')
stop_words = set(stop_words_df[0].values)

# 불용어 제거 함수
def remove_stopwords(text):
    words = mecab.nouns(text)
    words = [word for word in words if word not in stop_words]
    return ' '.join(words)

# 'clean_text' 컬럼에 대해 불용어 제거 함수 적용하여 'clean_text_2' 컬럼 생성
youth_sns_df['clean_text_2'] = youth_sns_df['clean_text'].apply(remove_stopwords)

# 결과 출력
youth_sns_df
# Out:
#               작성일              작성자  제목  \
# 0      2019/05/01  gyeongsangbukdo NaN
# 1      2019/05/01         imsena03 NaN
# 2      2019/05/01       mentorcore NaN
# 3      2019/05/01       maroon72kr NaN
# 4      2019/05/01         imsena03 NaN
# ...           ...              ...  ..
# 15894  2023/06/26      youthseoul_ NaN
# 15895  2023/06/26       zozomoonli NaN
# 15896  2023/06/26    ansancityhall NaN
# 15897  2023/06/26         tyche811 NaN
# 15898  2023/06/26   OhmyNews_Korea NaN
#
#                                                       내용     구분  \
# 0      #공예업체 _취업을 원하는 \n경북의 취준생들에게 꿀 정보??\n#경상북도 #청년정...    트위터
# 1      2019년 행정안전부 지역주도형 청년일자리 사업으로 선정된 「용인지역명소 활성화 추...  인스타그램
# 2      안양 핫플레이스 중 한곳인 롯데시네마 영화 상영관 표 확인하곳 바로 옆에 이렇게 청...  인스타그램
# 3      @Jaemyung_Lee 흠.. 트윗영상 업로드 펄러시가 바뀐게 확실해요.\n올리는...    트위터
# 4      2019년 청년인턴 추가채용 계획을 붙임과 같이 공고합니다. - 채용분야 및 인원 ...  인스타그램
# ...                                                  ...    ...
# ...

# %%
import re
#링크제거
link_pattern = r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

# %%
stop_words=[]

# stop_words를 제거하는 함수 정의
def remove_stop_words(text):
    global link_pattern  # link_pattern을 함수 내에서 사용하기 위해 global로 선언
    if isinstance(text, str):  # 문자열인지 확인
        text_without_links = re.sub(link_pattern, '', text)
        text_without_stop_words = ' '.join([word for word in text_without_links.split() if word not in stop_words])
        return text_without_stop_words.strip()  # 양쪽 공백 제거
    else:
        return text

# %%
youth_sns_df['clean_text_2'] = youth_sns_df['clean_text_2'].apply(remove_stop_words)
youth_sns_df = youth_sns_df.reset_index(drop=True)

# %% [markdown]
# ## 3. 토큰화

# %%
#토큰화함수
def mecab_tokenizer(sentence):
    if isinstance(sentence, str):
        return ' '.join(mecab.morphs(sentence))
    else:
        return ''  # 문자열이 아닌 경우 빈 문자열 반환

youth_sns_df['clean_contents'] = df['clean_text_2'].apply(mecab_tokenizer)

# %%
youth_sns_df.head()
# Out:
#           작성일              작성자  제목  \
# 0  2019/05/01  gyeongsangbukdo NaN
# 1  2019/05/01         imsena03 NaN
# 2  2019/05/01       mentorcore NaN
# 3  2019/05/01       maroon72kr NaN
# 4  2019/05/01         imsena03 NaN
#
#                                                   내용     구분  \
# 0  #공예업체 _취업을 원하는 \n경북의 취준생들에게 꿀 정보??\n#경상북도 #청년정...    트위터
# 1  2019년 행정안전부 지역주도형 청년일자리 사업으로 선정된 「용인지역명소 활성화 추...  인스타그램
# 2  안양 핫플레이스 중 한곳인 롯데시네마 영화 상영관 표 확인하곳 바로 옆에 이렇게 청...  인스타그램
# 3  @Jaemyung_Lee 흠.. 트윗영상 업로드 펄러시가 바뀐게 확실해요.\n올리는...    트위터
# 4  2019년 청년인턴 추가채용 계획을 붙임과 같이 공고합니다. - 채용분야 및 인원 ...  인스타그램
#
#                                           clean_text  \
# 0  공예업체 취업을 원하는 경북의 취준생들에게 꿀 정보 경상북도 청년정책 일자리정책 취...
# 1  년 행정안전부 지역주도형 청년일자리 사업으로 선정된 용인지역명소 활성화 추진단 참여...
# 2  안양 핫플레이스 중 한곳인 롯데시네마 영화 상영관 표 확인하곳 바로 옆에 이렇게 청...
# 3  흠 트윗영상 업로드 펄러시가 바뀐게 확실해요 올리는 영상의 길이를 임의로 조절을 못...
# 4  년 청년인턴 추가채용 계획을 붙임과 같이 공고합니다 채용분야 및 인원 가 채용분야 ...
#
#                                         clean_text_2  \
# ...

# %%
import MeCab

mecab = MeCab.Tagger()

# 결과를 엑셀 파일로 저장
output_path = '/gdrive/MyDrive/finalproject/datasets/youth_sns_df(ins,twitter)_final.xlsx'
df.to_excel(output_path, index=False)

# %% [markdown]
# - 스팸열 처리

# %%
output_path = '/gdrive/MyDrive/finalproject/datasets/youth_sns_df(ins,twitter)_final.xlsx'
df = pd.read_excel(output_path)

# %%
#스팸열 제거
spam_str = ['자동트윗','특강','캣맘','애견','하반기 뉴스','간추린뉴스','특수형광물질','호수마을 아파트','미사일','헤드라인','힙합엘이','조성진','김석진','마인드컨트롤전파무기','파리','그린가드','흥신소',
           '초음파검사','돌고래','부린이','오픈채팅방','문의전화','주식', '돈쭐','상담문의','광고문의','속도위반','역사교과서','일러스트레이터','데이트미팅','노사갈등',
            '동성결혼','마인드컨트롤','고속도로','음주운전'"차용증","아이유","일본어라 논의해야함","선지국","미국증시","하데스","인싸","오버워치","젠몬","오마이걸","파이어족","먹부림","서울지갑","안전운임제","샹젤리제"]
# Filter the DataFrame to remove rows containing the specified string
spam_condition = df['Summary'].apply(lambda x: not any(spam in x for spam in spam_str))
print(spam_condition)
df_filtered = df[spam_condition]
df_filtered.head()
df_filtered.info()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 34559    True
# 34560    True
# 34561    True
# 34562    True
# 34563    True
# Name: Summary, Length: 34564, dtype: bool
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 34526 entries, 0 to 34563
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      34526 non-null  object
#  1   User      34526 non-null  object
#  2   Contents  34526 non-null  object
#  3   Type      34526 non-null  object
#  4   Summary   34526 non-null  object
#  5   감성분석      34526 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 1.8+ MB

# %%
output_path = '/gdrive/MyDrive/finalproject/datasets/youth_sns_df(ins,twitter)_final.xlsx'
df_filtered.to_excel(output_path, index=False)

# %% [markdown]
# # 2. 블로그 커뮤니티 전처리

# %% [markdown]
# - 블로그&커뮤니티(최종)

# %%
import pandas as pd

# 합칠 Excel 파일의 경로
file_paths = ['/gdrive/MyDrive/finalproject/datasets/Raw/youthpolicy/Analysis_SnsData_20211001_20230626_(청년정책)&&~(rt__독취사)_BY_ARGOS.xlsx',
              '/gdrive/MyDrive/finalproject/datasets/Raw/youthpolicy/Analysis_SnsData_20190501_20210930_(청년정책)&&~(rt__독취사)_BY_ARGOS.xlsx']

# 빈 DataFrame 생성
youth_df = pd.DataFrame()

# 각 파일의 특정 시트를 읽어와서 DataFrame에 추가
for file_path in file_paths:
    xls = pd.ExcelFile(file_path)
    for sheet_name in xls.sheet_names:
        if sheet_name not in ['블로그', '커뮤니티']:  # 시트명이 "블로그" 또는 "커뮤니티"가 아닌 시트는 제외
            continue
        sheet_df = pd.read_excel(xls, sheet_name, skiprows=1)
        sheet_df['구분'] = sheet_name  # 시트명으로 구분하는 컬럼 추가
        youth_df = pd.concat([youth_df, sheet_df])

# '작성일' 기준으로 오름차순 정렬
youth_df = youth_df.sort_values(by='작성일')

# 합쳐진 DataFrame을 새로운 Excel 파일로 저장
output_path = '/gdrive/MyDrive/finalproject/datasets/final/youth_sns(blog,community)_df(test).xlsx'
youth_df.to_excel(output_path, index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 저장한 엑셀 파일의 경로
saved_excel_path = '/gdrive/MyDrive/finalproject/datasets/final/youth_sns(blog,community)_df(test).xlsx'

# 엑셀 파일을 DataFrame으로 읽어오기
youth_sns_df = pd.read_excel(saved_excel_path)

# DataFrame의 헤더 출력
youth_sns_df.head()
# Out:
#           작성일           작성자                                            제목  \
# 0  2019/05/01       lcnews9       \n청년구직활동지원금 선정자에게 ‘좋은 일자리’ 약속 한 고용노동부
# 1  2019/05/01  chosunsoon12          \n청년내일채움공제 과연 어떤 조건이 있을까 (자세히 알아보기)
# 2  2019/05/01      sisa2007                 591 - 유승희 국회의원, 청년문제 돌파구 찾는다!
# 3  2019/05/01     dudtn1688  \n[NCS 청년 서포터즈] 2019,NCS 청년 서포터즈 발대식을 다녀오다!
# 4  2019/05/01  gabriela_ran                                     \n감사한 나날
#
#                                                   내용   구분
# 0  http://www.lcnews.co.kr/news/articleView.html?...  블로그
# 1  #청년내일채움공제 #청년정책 #청년 #중소기업 #목돈마련 #가입조건 #개인 #기업 ...  블로그
# 2  \n﻿유승희 국회의원, 청년문제 돌파구 찾는다! \n고려대서 정책 토크콘서트 “기본...  블로그
# 3  안녕하세요! \n처음 여러분들에게 인사를 드리네요. \n이번 '2019 NCS 청년...  블로그
# 4  \n \n(서로의 동거인이 된 하요와 함께 찍은 사진) \n \n__ \n \n2월...  블로그

# %%
youth_sns_df.shape
# Out:
# (21050, 5)

# %% [markdown]
# ## 2-1. 결측치 제거

# %%
youth_sns_df.isna()
# Out:
#          작성일    작성자     제목     내용     구분
# 0      False  False  False  False  False
# 1      False  False  False  False  False
# 2      False  False  False  False  False
# 3      False  False  False  False  False
# 4      False  False  False  False  False
# ...      ...    ...    ...    ...    ...
# 21045  False  False  False  False  False
# 21046  False  False  False  False  False
# 21047  False  False  False  False  False
# 21048  False  False  False  False  False
# 21049  False  False  False  False  False
#
# [21050 rows x 5 columns]

# %%
youth_sns_df.dropna(inplace=True)
youth_sns_df.reset_index(drop=True, inplace = True)
youth_sns_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   작성일     20800 non-null  object
#  1   작성자     20800 non-null  object
#  2   제목      20800 non-null  object
#  3   내용      20800 non-null  object
#  4   구분      20800 non-null  object
# dtypes: object(5)
# memory usage: 812.6+ KB

# %%
youth_sns_df.head()
# Out:
#           작성일           작성자                                            제목  \
# 0  2019/05/01       lcnews9       \n청년구직활동지원금 선정자에게 ‘좋은 일자리’ 약속 한 고용노동부
# 1  2019/05/01  chosunsoon12          \n청년내일채움공제 과연 어떤 조건이 있을까 (자세히 알아보기)
# 2  2019/05/01      sisa2007                 591 - 유승희 국회의원, 청년문제 돌파구 찾는다!
# 3  2019/05/01     dudtn1688  \n[NCS 청년 서포터즈] 2019,NCS 청년 서포터즈 발대식을 다녀오다!
# 4  2019/05/01  gabriela_ran                                     \n감사한 나날
#
#                                                   내용   구분
# 0  http://www.lcnews.co.kr/news/articleView.html?...  블로그
# 1  #청년내일채움공제 #청년정책 #청년 #중소기업 #목돈마련 #가입조건 #개인 #기업 ...  블로그
# 2  \n﻿유승희 국회의원, 청년문제 돌파구 찾는다! \n고려대서 정책 토크콘서트 “기본...  블로그
# 3  안녕하세요! \n처음 여러분들에게 인사를 드리네요. \n이번 '2019 NCS 청년...  블로그
# 4  \n \n(서로의 동거인이 된 하요와 함께 찍은 사진) \n \n__ \n \n2월...  블로그

# %% [markdown]
# ## 2-2. 정제(Cleaning)
# - 정제(cleaning) : 갖고 있는 코퍼스(말뭉치)로부터 노이즈 데이터를 제거한다.

# %% [markdown]
# ### 전처리 사용자 정의 함수(최종 & 불용어 리스트 2차 필터)

# %%
# 완전 중복 행 제거
youth_sns_df = youth_sns_df.drop_duplicates()
youth_sns_df = youth_sns_df.reset_index(drop=True)

# '내용' 컬럼에 대해 전처리 함수 적용
youth_sns_df['clean_text'] = youth_sns_df['내용'].apply(text_preprocessor)
# 결측치를 빈 문자열로 처리하고 '제목' 컬럼에 대해 전처리 함수 적용
df_filtered['clean_title'] = df_filtered['clean_title'].fillna('').astype(str).apply(text_preprocessor)



# 완전 중복 행 제거
df_filtered = df_filtered.drop_duplicates()
df_filtered = df_filtered.reset_index(drop=True)


# 결과 출력
df_filtered

# 텍스트 전처리 사용자 정의함수(UDF of text pre-processing)
# Out:
#               작성일           작성자  \
# 0      2019/05/01  chosunsoon12
# 1      2019/05/01      sisa2007
# 2      2019/05/01     dudtn1688
# 3      2019/05/01  gabriela_ran
# 4      2019/05/01       giguc31
# ...           ...           ...
# 19462  2023/06/26     an_azure_
# 19463  2023/06/26         취업대학교
# 19464  2023/06/26         에펨코리아
# 19465  2023/06/26           노도강
# 19466  2023/06/26         에펨코리아
#
#                                                       제목  \
# 0                   \n청년내일채움공제 과연 어떤 조건이 있을까 (자세히 알아보기)
# 1                          591 - 유승희 국회의원, 청년문제 돌파구 찾는다!
# 2           \n[NCS 청년 서포터즈] 2019,NCS 청년 서포터즈 발대식을 다녀오다!
# 3                                              \n감사한 나날
# 4                   \n[청년정책 멘토링] 내가 도움받을 수 있는 정책은 무엇일까?
# ...                                                  ...
# 19462  [청년DB] 정책에 관심있는 2030 청년들이여, 주목하라! 청년 참여 플랫폼 - ...
# 19463                        기획재정부 청년 정책들.. 알아두면 좋을거 같아요
# ...

# %%
# 'clean_text' 컬럼에 대해 불용어 제거 함수 적용하여 'clean_text_2' 컬럼 생성
youth_sns_df['clean_text_2'] = youth_sns_df['clean_text_2'].apply(remove_stopwords)

youth_sns_df = youth_sns_df.reset_index(drop=True)

# %% [markdown]
# ## 3. 토큰화

# %%
youth_sns_df['clean_title'] = youth_sns_df['제목'].apply(mecab_tokenizer)
youth_sns_df['clean_contents'] = youth_sns_df['clean_text_2'].apply(mecab_tokenizer)

youth_sns_df.head()
# Out:
#           작성일           작성자                                            제목  \
# 0  2019/05/01  chosunsoon12          \n청년내일채움공제 과연 어떤 조건이 있을까 (자세히 알아보기)
# 1  2019/05/01      sisa2007                 591 - 유승희 국회의원, 청년문제 돌파구 찾는다!
# 2  2019/05/01     dudtn1688  \n[NCS 청년 서포터즈] 2019,NCS 청년 서포터즈 발대식을 다녀오다!
# 3  2019/05/01  gabriela_ran                                     \n감사한 나날
# 4  2019/05/01       giguc31          \n[청년정책 멘토링] 내가 도움받을 수 있는 정책은 무엇일까?
#
#                                                   내용   구분  \
# 0  #청년내일채움공제 #청년정책 #청년 #중소기업 #목돈마련 #가입조건 #개인 #기업 ...  블로그
# 1  \n﻿유승희 국회의원, 청년문제 돌파구 찾는다! \n고려대서 정책 토크콘서트 “기본...  블로그
# 2  안녕하세요! \n처음 여러분들에게 인사를 드리네요. \n이번 '2019 NCS 청년...  블로그
# 3  \n \n(서로의 동거인이 된 하요와 함께 찍은 사진) \n \n__ \n \n2월...  블로그
# 4  안녕하세요! 청춘 너나들이 서포터즈 권성빈입니다. \n청춘 너나들이에서 청년들의 취...  블로그
#
#                                           clean_text  \
# 0  청년내일채움공제 청년정책 청년 중소기업 목돈마련 가입조건 개인 기업 안녕하세요 잡다...
# 1  유승희 국회의원 청년문제 돌파구 찾는다 고려대서 정책 토크콘서트 기본소득 스타트업 ...
# ...

# %%
import MeCab
mecab = MeCab.Tagger()

# 결과를 엑셀 파일로 저장
output_path = "/gdrive/MyDrive/finalproject/datasets/youth_sns_df(blog,community)_final.xlsx"
df.to_excel(output_path, index=False)

# %%
output_path = "/gdrive/MyDrive/finalproject/datasets/youth_sns_df(blog,community)_final.xlsx"
df = pd.read_excel(output_path)

# %%
#스팸열 제거
spam_str = ['자동트윗','특강','캣맘','애견','하반기 뉴스','간추린뉴스','특수형광물질','호수마을 아파트','미사일','헤드라인','힙합엘이','조성진','김석진','마인드컨트롤전파무기','파리','그린가드','흥신소',
           '초음파검사','돌고래','부린이','오픈채팅방','문의전화','주식', '돈쭐','상담문의','광고문의','속도위반','역사교과서','일러스트레이터','데이트미팅','노사갈등',
            '동성결혼','마인드컨트롤','고속도로','음주운전'"차용증","아이유","일본어라 논의해야함","선지국","미국증시","하데스","인싸","오버워치","젠몬","오마이걸","파이어족","먹부림","서울지갑","안전운임제","샹젤리제"]
# Filter the DataFrame to remove rows containing the specified string
spam_condition = df['내용'].apply(lambda x: not any(spam in x for spam in spam_str))
print(spam_condition)
df_filtered = df[spam_condition]
df_filtered.head()
df_filtered.info()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 19586    True
# 19587    True
# 19588    True
# 19589    True
# 19590    True
# Name: 내용, Length: 19591, dtype: bool
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19467 entries, 0 to 19590
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   작성일             19467 non-null  object
#  1   작성자             19467 non-null  object
#  2   제목              19467 non-null  object
#  3   내용              19467 non-null  object
#  4   구분              19467 non-null  object
#  5   clean_text      19343 non-null  object
#  6   clean_text_2    19338 non-null  object
#  7   clean_title     19464 non-null  object
#  8   clean_contents  19338 non-null  object
# dtypes: object(9)
# memory usage: 1.5+ MB

# %%
df_filtered
# Out:
#               작성일           작성자  \
# 0      2019/05/01  chosunsoon12
# 1      2019/05/01      sisa2007
# 2      2019/05/01     dudtn1688
# 3      2019/05/01  gabriela_ran
# 4      2019/05/01       giguc31
# ...           ...           ...
# 19586  2023/06/26     an_azure_
# 19587  2023/06/26         취업대학교
# 19588  2023/06/26         에펨코리아
# 19589  2023/06/26           노도강
# 19590  2023/06/26         에펨코리아
#
#                                                       제목  \
# 0                   \n청년내일채움공제 과연 어떤 조건이 있을까 (자세히 알아보기)
# 1                          591 - 유승희 국회의원, 청년문제 돌파구 찾는다!
# 2           \n[NCS 청년 서포터즈] 2019,NCS 청년 서포터즈 발대식을 다녀오다!
# 3                                              \n감사한 나날
# 4                   \n[청년정책 멘토링] 내가 도움받을 수 있는 정책은 무엇일까?
# ...                                                  ...
# 19586  [청년DB] 정책에 관심있는 2030 청년들이여, 주목하라! 청년 참여 플랫폼 - ...
# 19587                        기획재정부 청년 정책들.. 알아두면 좋을거 같아요
# ...

# %%
output_path = "/gdrive/MyDrive/finalproject/datasets/youth_sns_df(blog,community)_final.xlsx"
df_filtered.to_excel(output_path, index=False)

# %% [markdown]
# # 3. 뉴스 전처리

# %% [markdown]
# ## - Package 설치

# %%
# 합칠 Excel 파일의 경로
file_paths = ['/gdrive/MyDrive/finalproject/datasets/Raw/youthpolicy/youth_policy_news(20211001_20230626).xlsx',
              '/gdrive/MyDrive/finalproject/datasets/Raw/youthpolicy/youth_policy_news(20190501_20210930).xlsx']

# 각 파일을 DataFrame으로 읽어오기
df_list = [pd.read_excel(file_path, skiprows=1) for file_path in file_paths]

# DataFrame 합치기
youth_df = pd.concat(df_list)

# '작성일' 기준으로 오름차순 정렬
youth_df = youth_df.sort_values(by='작성일')

# 합쳐진 DataFrame을 새로운 Excel 파일로 저장
youth_df.to_excel('/gdrive/MyDrive/finalproject/datasets/final/youth_news_df(test).xlsx', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
# 저장한 엑셀 파일의 경로
saved_excel_path = '/gdrive/MyDrive/finalproject/datasets/final/youth_news_df(test).xlsx'

# 엑셀 파일을 DataFrame으로 읽어오기
youth_news_df = pd.read_excel(saved_excel_path)

# DataFrame의 헤더 출력
youth_news_df.head()
# Out:
#           작성일     작성자                                  제목  \
# 0  2019/05/01    강원일보                      [강릉]청년정책보고회 개최
# 1  2019/05/01    노컷뉴스  경남 떠난 청년들 '부산으로'...일자리 찾으러 '수도권으로'
# 2  2019/05/01    서울신문           경기도, 토론에 꽂혔다… 시민 아이디어 꽃폈다
# 3  2019/05/01  파이낸셜뉴스           박승원 광명시장 “광명형 청년정책 본격 추진”
# 4  2019/05/01     뉴스1          文대통령, 사회원로와 오찬 간담회…2일 주요일정
#
#                                                   내용
# 0  【강릉】강릉시는 지난 30일 시청 18층 전망대에서 현재 청년 관련 정책을 추진하고...
# 1  경남발전연구원 심인선 선임연구위원 연구보고서 유출 청년 30.7% 부산 이동, 일자...
# 2  경기 자치단체 ‘토론문화’ 바람 [서울신문] 주민 참여 토론의 장 만들어 의견 수렴...
# 3  광명시‘시장 직속 청년 위원회’ 출범식. 사진제공=광명시               ...
# 4  문재인 대통령. (청와대 제공) 2019.4.30/뉴스1 ◇文대통령, 김영란·윤여준...

# %%
youth_news_df.shape
# Out:
# (18927, 4)

# %% [markdown]
# ## 2-1. 결측치,중복값 제거

# %% [markdown]
# - 결측치 제거

# %%
youth_news_df.isna()
# Out:
#          작성일    작성자     제목     내용
# 0      False  False  False  False
# 1      False  False  False  False
# 2      False  False  False  False
# 3      False  False  False  False
# 4      False  False  False  False
# ...      ...    ...    ...    ...
# 18922  False  False  False  False
# 18923  False  False  False  False
# 18924  False  False  False  False
# 18925  False  False  False  False
# 18926  False  False  False  False
#
# [18927 rows x 4 columns]

# %%
youth_news_df.dropna(inplace=True)
youth_news_df.reset_index(drop=True, inplace = True)
youth_news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18920 entries, 0 to 18919
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   작성일     18920 non-null  object
#  1   작성자     18920 non-null  object
#  2   제목      18920 non-null  object
#  3   내용      18920 non-null  object
# dtypes: object(4)
# memory usage: 591.4+ KB

# %%
youth_news_df.head()
# Out:
#           작성일     작성자                                  제목  \
# 0  2019/05/01    강원일보                      [강릉]청년정책보고회 개최
# 1  2019/05/01    노컷뉴스  경남 떠난 청년들 '부산으로'...일자리 찾으러 '수도권으로'
# 2  2019/05/01    서울신문           경기도, 토론에 꽂혔다… 시민 아이디어 꽃폈다
# 3  2019/05/01  파이낸셜뉴스           박승원 광명시장 “광명형 청년정책 본격 추진”
# 4  2019/05/01     뉴스1          文대통령, 사회원로와 오찬 간담회…2일 주요일정
#
#                                                   내용
# 0  【강릉】강릉시는 지난 30일 시청 18층 전망대에서 현재 청년 관련 정책을 추진하고...
# 1  경남발전연구원 심인선 선임연구위원 연구보고서 유출 청년 30.7% 부산 이동, 일자...
# 2  경기 자치단체 ‘토론문화’ 바람 [서울신문] 주민 참여 토론의 장 만들어 의견 수렴...
# 3  광명시‘시장 직속 청년 위원회’ 출범식. 사진제공=광명시               ...
# 4  문재인 대통령. (청와대 제공) 2019.4.30/뉴스1 ◇文대통령, 김영란·윤여준...

# %% [markdown]
# - '제목', '내용' 컬럼 중복값 제거

# %%
# 데이터프레임 컬럼의 값을 문자열로 변환
column_name = ['제목','내용']  # 변환할 컬럼의 이름으로 수정
youth_news_df = youth_news_df.fillna('')
youth_news_df[column_name] = youth_news_df[column_name].astype(str)

# 중복 제거 전 데이터프레임 복사
youth_news_df_before_duplicates = youth_news_df.copy()

# 중복 제거 후 데이터프레임
youth_news_df.drop_duplicates(subset=column_name, keep='first', inplace=True)

# 중복 제거 전후의 결과 출력
print("제목 칼럼의 중복값이 제거된 고유 값 개수:", youth_news_df['제목'].nunique())
print("내용 칼럼의 중복값이 제거된 고유 값 개수:", youth_news_df['내용'].nunique())

youth_news_df
# Out:
# 제목 칼럼의 중복값이 제거된 고유 값 개수: 18558
# 내용 칼럼의 중복값이 제거된 고유 값 개수: 18774
#               작성일     작성자                                      제목  \
# 0      2019/05/01    강원일보                          [강릉]청년정책보고회 개최
# 1      2019/05/01    노컷뉴스      경남 떠난 청년들 '부산으로'...일자리 찾으러 '수도권으로'
# 2      2019/05/01    서울신문               경기도, 토론에 꽂혔다… 시민 아이디어 꽃폈다
# 3      2019/05/01  파이낸셜뉴스               박승원 광명시장 “광명형 청년정책 본격 추진”
# 4      2019/05/01     뉴스1              文대통령, 사회원로와 오찬 간담회…2일 주요일정
# ...           ...     ...                                     ...
# 18915  2023/06/26    중앙일보     [단독]與, 취준생 정보 파기·고지 의무화…공무원 무단열람 제한
# 18916  2023/06/26  아이뉴스24                       익산형 청년근로수당 `인기몰이`
# 18917  2023/06/26  아이뉴스24         조근제 함안군수 “함안을 세계적 관광도시로 도약시키겠다”
# 18918  2023/06/26   오마이뉴스     강남구의회 우종혁 의원, 청년정책 및 녹색건축물 조성 사업 지원
# 18919  2023/06/26  아이뉴스24  국민의힘 대구 수성구을 홍보위원회, 강사빈 부대변인 초청 간담회 성료
#
#                                                       내용
# ...

# %%
youth_news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18857 entries, 0 to 18919
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   작성일     18857 non-null  object
#  1   작성자     18857 non-null  object
#  2   제목      18857 non-null  object
#  3   내용      18857 non-null  object
# dtypes: object(4)
# memory usage: 736.6+ KB

# %% [markdown]
# ## 2-2. 정제(Cleaning)
# - 정제(cleaning) : 갖고 있는 코퍼스(말뭉치)로부터 노이즈 데이터를 제거한다.

# %% [markdown]
# ### 전처리 사용자 정의 함수(최종 & 불용어 리스트 2차 필터)

# %%
# 완전 중복 행 제거
youth_news_df = youth_news_df.drop_duplicates()
youth_news_df = youth_news_df.reset_index(drop=True)

# '내용' 컬럼에 대해 전처리 함수 적용
youth_news_df['clean_text'] = youth_news_df['내용'].apply(text_preprocessor)
youth_news_df['clean_title'] = youth_news_df['제목'].apply(text_preprocessor)

# 결과 출력
youth_news_df
# Out:
#               작성일     작성자                                      제목  \
# 0      2019/05/01    강원일보                          [강릉]청년정책보고회 개최
# 1      2019/05/01    노컷뉴스      경남 떠난 청년들 '부산으로'...일자리 찾으러 '수도권으로'
# 2      2019/05/01    서울신문               경기도, 토론에 꽂혔다… 시민 아이디어 꽃폈다
# 3      2019/05/01  파이낸셜뉴스               박승원 광명시장 “광명형 청년정책 본격 추진”
# 4      2019/05/01     뉴스1              文대통령, 사회원로와 오찬 간담회…2일 주요일정
# ...           ...     ...                                     ...
# 18852  2023/06/26    중앙일보     [단독]與, 취준생 정보 파기·고지 의무화…공무원 무단열람 제한
# 18853  2023/06/26  아이뉴스24                       익산형 청년근로수당 `인기몰이`
# 18854  2023/06/26  아이뉴스24         조근제 함안군수 “함안을 세계적 관광도시로 도약시키겠다”
# 18855  2023/06/26   오마이뉴스     강남구의회 우종혁 의원, 청년정책 및 녹색건축물 조성 사업 지원
# 18856  2023/06/26  아이뉴스24  국민의힘 대구 수성구을 홍보위원회, 강사빈 부대변인 초청 간담회 성료
#
#                                                       내용  \
# 0      【강릉】강릉시는 지난 30일 시청 18층 전망대에서 현재 청년 관련 정책을 추진하고...
# ...

# %%
# 'clean_text' 컬럼에 대해 불용어 제거 함수 적용하여 'clean_text_2' 컬럼 생성
youth_news_df['clean_text_2'] = youth_news_df['clean_text'].apply(remove_stopwords)
youth_news_df['clean_title'] = youth_news_df['clean_title'].apply(remove_stopwords)

# 결과 출력
youth_news_df
# Out:
#               작성일     작성자                                      제목  \
# 0      2019/05/01    강원일보                          [강릉]청년정책보고회 개최
# 1      2019/05/01    노컷뉴스      경남 떠난 청년들 '부산으로'...일자리 찾으러 '수도권으로'
# 2      2019/05/01    서울신문               경기도, 토론에 꽂혔다… 시민 아이디어 꽃폈다
# 3      2019/05/01  파이낸셜뉴스               박승원 광명시장 “광명형 청년정책 본격 추진”
# 4      2019/05/01     뉴스1              文대통령, 사회원로와 오찬 간담회…2일 주요일정
# ...           ...     ...                                     ...
# 18852  2023/06/26    중앙일보     [단독]與, 취준생 정보 파기·고지 의무화…공무원 무단열람 제한
# 18853  2023/06/26  아이뉴스24                       익산형 청년근로수당 `인기몰이`
# 18854  2023/06/26  아이뉴스24         조근제 함안군수 “함안을 세계적 관광도시로 도약시키겠다”
# 18855  2023/06/26   오마이뉴스     강남구의회 우종혁 의원, 청년정책 및 녹색건축물 조성 사업 지원
# 18856  2023/06/26  아이뉴스24  국민의힘 대구 수성구을 홍보위원회, 강사빈 부대변인 초청 간담회 성료
#
#                                                       내용  \
# 0      【강릉】강릉시는 지난 30일 시청 18층 전망대에서 현재 청년 관련 정책을 추진하고...
# ...

# %%
youth_news_df['clean_text_2'] = youth_news_df['clean_text_2'].apply(remove_stop_words)
youth_news_df = youth_news_df.reset_index(drop=True)

# %% [markdown]
# ## 3. 토큰화

# %%
def mecab_tokenizer(sentence):
    return ' '.join(mecab.morphs(sentence)) # 토큰을 띄어쓰기 단위로 구분

youth_news_df['clean_title'] = youth_news_df['clean_title'].apply(mecab_tokenizer)
youth_news_df['clean_contents'] = youth_news_df['clean_text_2'].apply(mecab_tokenizer)

# %%
youth_news_df.head()
# Out:
#           작성일     작성자                                  제목  \
# 0  2019/05/01    강원일보                      [강릉]청년정책보고회 개최
# 1  2019/05/01    노컷뉴스  경남 떠난 청년들 '부산으로'...일자리 찾으러 '수도권으로'
# 2  2019/05/01    서울신문           경기도, 토론에 꽂혔다… 시민 아이디어 꽃폈다
# 3  2019/05/01  파이낸셜뉴스           박승원 광명시장 “광명형 청년정책 본격 추진”
# 4  2019/05/01     뉴스1          文대통령, 사회원로와 오찬 간담회…2일 주요일정
#
#                                                   내용  \
# 0  【강릉】강릉시는 지난 30일 시청 18층 전망대에서 현재 청년 관련 정책을 추진하고...
# 1  경남발전연구원 심인선 선임연구위원 연구보고서 유출 청년 30.7% 부산 이동, 일자...
# 2  경기 자치단체 ‘토론문화’ 바람 [서울신문] 주민 참여 토론의 장 만들어 의견 수렴...
# 3  광명시‘시장 직속 청년 위원회’ 출범식. 사진제공=광명시               ...
# 4  문재인 대통령. (청와대 제공) 2019.4.30/뉴스1 ◇文대통령, 김영란·윤여준...
#
#                                           clean_text  \
# 0   강릉 강릉시는 지난   일 시청   층 전망대에서 현재 청년 관련 정책을 추진하고...
# 1  경남발전연구원 심인선 선임연구위원 연구보고서 유출 청년       부산 이동  일자...
# 2  경기 자치단체  토론문화  바람    주민 참여 토론의 장 만들어 의견 수렴  경제...
# 3  광명시 시장 직속 청년 위원회  출범식  사진제공 광명시               ...
# ...

# %%
import MeCab

mecab = MeCab.Tagger()

# 결과를 엑셀 파일로 저장
output_path = '/gdrive/MyDrive/finalproject/datasets/final/youth_news_df_final.xlsx'
youth_news_df.to_excel(output_path, index=False)

# %%
output_path = '/gdrive/MyDrive/finalproject/datasets/final/youth_news_df_final.xlsx'
youth_news_df=pd.read_excel(output_path)

# %%
# clean_text_2 컬럼과 clean_contents 컬럼을 합쳐서 summary 컬럼 생성
youth_news_df['summary'] = youth_news_df['clean_title'] + ' ' + youth_news_df['clean_contents']

youth_news_df
# Out:
#               작성일     작성자                                      제목  \
# 0      2019/05/01    강원일보                          [강릉]청년정책보고회 개최
# 1      2019/05/01    노컷뉴스      경남 떠난 청년들 '부산으로'...일자리 찾으러 '수도권으로'
# 2      2019/05/01    서울신문               경기도, 토론에 꽂혔다… 시민 아이디어 꽃폈다
# 3      2019/05/01  파이낸셜뉴스               박승원 광명시장 “광명형 청년정책 본격 추진”
# 4      2019/05/01     뉴스1              文대통령, 사회원로와 오찬 간담회…2일 주요일정
# ...           ...     ...                                     ...
# 18852  2023/06/26    중앙일보     [단독]與, 취준생 정보 파기·고지 의무화…공무원 무단열람 제한
# 18853  2023/06/26  아이뉴스24                       익산형 청년근로수당 `인기몰이`
# 18854  2023/06/26  아이뉴스24         조근제 함안군수 “함안을 세계적 관광도시로 도약시키겠다”
# 18855  2023/06/26   오마이뉴스     강남구의회 우종혁 의원, 청년정책 및 녹색건축물 조성 사업 지원
# 18856  2023/06/26  아이뉴스24  국민의힘 대구 수성구을 홍보위원회, 강사빈 부대변인 초청 간담회 성료
#
#                                                       내용  \
# 0      【강릉】강릉시는 지난 30일 시청 18층 전망대에서 현재 청년 관련 정책을 추진하고...
# ...

# %%
output_path = '/gdrive/MyDrive/finalproject/datasets/final/youth_news_df_final.xlsx'
youth_news_df.to_excel(output_path, index=False)
